# %%
import pandas as pd
import statistics

# %%
df = pd.read_csv("country_vaccination_stats.csv")

# %%
df.head()
# Out:
#      country        date  daily_vaccinations   vaccines
# 0  Argentina  12/29/2020                 NaN  Sputnik V
# 1  Argentina  12/30/2020             15656.0  Sputnik V
# 2  Argentina  12/31/2020             15656.0  Sputnik V
# 3  Argentina    1/1/2021             11070.0  Sputnik V
# 4  Argentina    1/2/2021              8776.0  Sputnik V

# %%
df = df.fillna(0)

# %%
medyan=df.groupby('country').median()
medyan
# Out:
#                       daily_vaccinations
# country
# Argentina                        11645.0
# Austria                           7850.0
# Bahrain                           3662.0
# Belgium                           3606.0
# Brazil                           17220.0
# Bulgaria                          1010.0
# Canada                           11044.0
# Chile                             1291.0
# China                           276786.0
# Costa Rica                         675.5
# Croatia                           2485.0
# Cyprus                             708.0
# Czechia                           5378.0
# Denmark                           7095.5
# Ecuador                             54.0
# England                         107310.5
# Estonia                           1043.0
# Finland                           2035.5
# France                           41496.0
# Germany                          51184.0
# Gibraltar                          713.0
# Greece                            5290.0
# ...

# %%
medyan.sort_values('daily_vaccinations', ascending=False).head(3)
# Out:
#                daily_vaccinations
# country
# United States            378253.0
# China                    276786.0
# India                    173922.0
